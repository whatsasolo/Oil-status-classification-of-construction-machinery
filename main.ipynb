# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = './data/'

df = pd.read_csv('./data/train.csv')
df_test = pd.read_csv('./data/test.csv')

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(16,5))

sns.heatmap(df.T.isna(), cmap='Blues')
ax.set_title('Missing Values', fontsize=16)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12)
plt.show()
# Out:
# /var/folders/3d/fksyvw8102q5p7zbsjrk_qs80000gn/T/ipykernel_18730/755468324.py:7: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(12)

# %%
df[list(set(df.columns) - (set(df.columns) - set(df_test.columns)))].columns
# Out:
# Index(['NI', 'PQINDEX', 'MO', 'CR', 'ZN', 'CO', 'ANONYMOUS_1', 'CU', 'V40',
#        'MN', 'YEAR', 'H2O', 'ANONYMOUS_2', 'AG', 'V', 'COMPONENT_ARBITRARY',
#        'ID', 'FE', 'TI'],
#       dtype='object')

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(16,5))

sns.heatmap(df[list(set(df.columns) - (set(df.columns) - set(df_test.columns)))].T.isna(), cmap='Blues')
ax.set_title('Missing Values', fontsize=16)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12)
plt.show()
# Out:
# /var/folders/3d/fksyvw8102q5p7zbsjrk_qs80000gn/T/ipykernel_18730/68764265.py:7: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(12)

# %%
df.Y_LABEL.mean()
# Out:
# 0.08534941468605889

# %%
df
# Out:
#                 ID COMPONENT_ARBITRARY  ANONYMOUS_1  YEAR  \
# 0      TRAIN_00000          COMPONENT3         1486  2011
# 1      TRAIN_00001          COMPONENT2         1350  2021
# 2      TRAIN_00002          COMPONENT2         2415  2015
# 3      TRAIN_00003          COMPONENT3         7389  2010
# 4      TRAIN_00004          COMPONENT3         3954  2015
# ...            ...                 ...          ...   ...
# 14090  TRAIN_14090          COMPONENT3         1616  2014
# 14091  TRAIN_14091          COMPONENT1         2784  2013
# 14092  TRAIN_14092          COMPONENT3         1788  2008
# 14093  TRAIN_14093          COMPONENT2         2498  2009
# 14094  TRAIN_14094          COMPONENT2         1902  2012
#
#        SAMPLE_TRANSFER_DAY  ANONYMOUS_2  AG   AL    B  BA  ...     U25  \
# 0                        7          200   0    3   93   0  ...     NaN
# 1                       51          375   0    2   19   0  ...     2.0
# ...

# %%
df.describe()
# Out:
#          ANONYMOUS_1          YEAR  SAMPLE_TRANSFER_DAY   ANONYMOUS_2  \
# count   14095.000000  14095.000000         14095.000000  14095.000000
# mean     3146.082937   2013.652501             7.600568    387.416885
# std      4216.089809      3.964758            11.681628    550.016073
# min      1000.000000   2007.000000             0.000000    200.000000
# 25%      1655.000000   2010.000000             3.000000    200.000000
# 50%      2227.000000   2014.000000             5.000000    200.000000
# 75%      3797.000000   2017.000000             8.000000    410.000000
# max    294451.000000   2022.000000           368.000000   9650.000000
#
#                  AG            AL             B            BA            BE  \
# count  14095.000000  14095.000000  14095.000000  14095.000000  14095.000000
# mean       0.025825     12.707698     64.026179      0.692799      0.006314
# std        0.171926     86.968000    102.876871      2.905491      0.152189
# ...

# %%
df[df.Y_LABEL == 1].describe()
# Out:
#         ANONYMOUS_1         YEAR  SAMPLE_TRANSFER_DAY  ANONYMOUS_2  \
# count   1203.000000  1203.000000          1203.000000  1203.000000
# mean    3756.068163  2012.512053             7.435578   326.846218
# std     3685.434277     3.955091            10.914193   462.835012
# min     1000.000000  2007.000000             0.000000   200.000000
# 25%     1837.000000  2009.000000             3.000000   200.000000
# 50%     2790.000000  2012.000000             5.000000   200.000000
# 75%     4604.500000  2015.000000             8.000000   200.000000
# max    64580.000000  2022.000000           146.000000  7900.000000
#
#                 AG           AL            B           BA           BE  \
# count  1203.000000  1203.000000  1203.000000  1203.000000  1203.000000
# mean      0.034081   118.188695    53.995012     1.689942     0.011638
# std       0.194779   276.348977    80.474901     3.084143     0.226815
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %%
plt.figure(figsize=(18,30))
plt.tight_layout()
plt.subplots_adjust(hspace=0.3)
for index,col in enumerate(df.columns[1:]):
    plt.subplot(4,13,index+1)
    sns.lineplot(data = df, x = df['ID'], y = df[col])
    plt.title(f'amount of {col}',fontsize = 16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [10], line 5
#       3 plt.subplots_adjust(hspace=0.3)
#       4 for index,col in enumerate(df.columns[1:]):
# ----> 5     plt.subplot(4,13,index+1)
#       6     sns.lineplot(data = df, x = df['ID'], y = df[col])
#       7     plt.title(f'amount of {col}',fontsize = 16)
#
# File ~/miniforge3/envs/tch/lib/python3.8/site-packages/matplotlib/pyplot.py:1252, in subplot(*args, **kwargs)
#    1249 fig = gcf()
#    1251 # First, search for an existing subplot with a matching spec.
# -> 1252 key = SubplotSpec._from_subplot_args(fig, args)
#    1254 for ax in fig.axes:
#    1255     # if we found an Axes at the position sort out if we can re-use it
#    1256     if hasattr(ax, 'get_subplotspec') and ax.get_subplotspec() == key:
#    1257         # if the user passed no kwargs, re-use
#
# ...

# %%
plt.figure(figsize=(18,30))
plt.tight_layout()
plt.subplots_adjust(hspace=0.3)
for index,col in enumerate(df.columns[1:]):
    plt.subplot(2,2,index+1)
    sns.lineplot(data = df, x = df['ID'], y = df[col])
    plt.title(f'amount of {col}',fontsize = 16)
plt.show()

# %%
df.columns[1:-1]
# Out:
# Index(['COMPONENT_ARBITRARY', 'ANONYMOUS_1', 'YEAR', 'SAMPLE_TRANSFER_DAY',
#        'ANONYMOUS_2', 'AG', 'AL', 'B', 'BA', 'BE', 'CA', 'CD', 'CO', 'CR',
#        'CU', 'FH2O', 'FNOX', 'FOPTIMETHGLY', 'FOXID', 'FSO4', 'FTBN', 'FE',
#        'FUEL', 'H2O', 'K', 'LI', 'MG', 'MN', 'MO', 'NA', 'NI', 'P', 'PB',
#        'PQINDEX', 'S', 'SB', 'SI', 'SN', 'SOOTPERCENTAGE', 'TI', 'U100', 'U75',
#        'U50', 'U25', 'U20', 'U14', 'U6', 'U4', 'V', 'V100', 'V40', 'ZN'],
#       dtype='object')

# %%
for i in range(0,52,4):
    for index,col in enumerate(df.columns[i+1:i+5]):
        plt.subplot(2,2,index+1)
        sns.lineplot(data = df, x = df['ID'], y = df[col])
        plt.title(f'amount of {col}',fontsize = 9)
        plt.xticks(rotation = -90)
    plt.grid()
    plt.show()
