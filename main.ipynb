# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = './data/'

df = pd.read_csv('./data/train.csv')
df_test = pd.read_csv('./data/test.csv')

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(16,5))

sns.heatmap(df.T.isna(), cmap='Blues')
ax.set_title('Missing Values', fontsize=16)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12)
plt.show()
# Out:
# /var/folders/3d/fksyvw8102q5p7zbsjrk_qs80000gn/T/ipykernel_33735/755468324.py:7: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(12)

# %%
df[list(set(df.columns) - (set(df.columns) - set(df_test.columns)))].columns
# Out:
# Index(['MO', 'CU', 'MN', 'ANONYMOUS_2', 'TI', 'CO', 'NI', 'ID',
#        'COMPONENT_ARBITRARY', 'V', 'H2O', 'ANONYMOUS_1', 'AG', 'V40', 'YEAR',
#        'CR', 'PQINDEX', 'ZN', 'FE'],
#       dtype='object')

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(16,5))

sns.heatmap(df[list(set(df.columns) - (set(df.columns) - set(df_test.columns)))].T.isna(), cmap='Blues')
ax.set_title('Missing Values', fontsize=16)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12)
plt.show()
# Out:
# /var/folders/3d/fksyvw8102q5p7zbsjrk_qs80000gn/T/ipykernel_33663/68764265.py:7: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(12)

# %%
df.Y_LABEL.mean()
# Out:
# 0.08534941468605889

# %%
df.COMPONENT_ARBITRARY = df.COMPONENT_ARBITRARY.apply(lambda x : int(x[-1]))

# %%
df
# Out:
#                 ID  COMPONENT_ARBITRARY  ANONYMOUS_1  YEAR  \
# 0      TRAIN_00000                    3         1486  2011
# 1      TRAIN_00001                    2         1350  2021
# 2      TRAIN_00002                    2         2415  2015
# 3      TRAIN_00003                    3         7389  2010
# 4      TRAIN_00004                    3         3954  2015
# ...            ...                  ...          ...   ...
# 14090  TRAIN_14090                    3         1616  2014
# 14091  TRAIN_14091                    1         2784  2013
# 14092  TRAIN_14092                    3         1788  2008
# 14093  TRAIN_14093                    2         2498  2009
# 14094  TRAIN_14094                    2         1902  2012
#
#        SAMPLE_TRANSFER_DAY  ANONYMOUS_2  AG   AL    B  BA  ...     U25  \
# 0                        7          200   0    3   93   0  ...     NaN
# 1                       51          375   0    2   19   0  ...     2.0
# ...

# %%
sns.kdeplot(data = df.CD, shade = True)
# Out:
# /var/folders/3d/fksyvw8102q5p7zbsjrk_qs80000gn/T/ipykernel_33735/25156470.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data = df.CD, shade = True)
# <AxesSubplot: xlabel='CD', ylabel='Density'>

# %% [markdown]
# |Feature Name|Description|처리 방법 및 비고|
# |------------|-----------|-------------:|
# |COMPONENT_ARBITRARY|샘플 오일 관련 부품 (Component 4종, 비식별화)|결측치 없음|
# |ANONYMOUS_1|무명 Feautre 1. 수치형 데이터|결측치 없음|
# |YEAR|오일 샘플 및 진단 해 (Year)|결측치 없음|
# |SAMPLE_TRANSFER_DAY|오일 샘플링 후 진단 기관으로 이동한 기간 (Days)|결측치 없음|
# |ANONYMOUS_2|무명 Feautre 2. 수치형 데이터|결측치 없음|
# |AG|원소기호 AG - Silver 함유량|결측치 없음|
# |AL|원소기호 AL - Aluminium 함유량|결측치 없음|
# |B|원소기호 B - Boron 함유량|결측치 없음|
# |BA|원소기호 BA - Barium 함유량|결측치 없음|
# |BE|원소기호 BE - Beryllium 함유량|결측치 없음|
# |CA|원소기호 CA - Calcium 함유량|결측치 없음|
# |CD|~~원소기호 CD - Cadmium 함유량~~|결측치 ->0|
# |CO|원소기호 CO - Cobolt 함유량|결측치 없음|
# |CR|원소기호 CR - Chromium 함유량|결측치 없음|
# |CU|원소기호 CU - Copper 함유량|결측치 없음|
# |FH2O|Water 수치(By FT-IR)||
# |FNOX|NOx 수치(By FT-IR)||
# |FOPTIMETHGLY|비식별화||
# |FOXID|Oxidation 수치(By FT-IR)||
# |FSO4|SO4 수치(By FT-IR)||
# |FTBN|염기성 첨가제물질 수치(By FT-IR)||
# |FE|원소기호 FE - Iron 함유량||
# |FUEL|연료 함유량||
# |H2O|Water 함유량||
# |K|원소기호 K - Potassium 함유량||
# |LI|원소기호 LI - Lithium 함유량||
# |MG|원소기호 MG - Magnesium 함유량||
# |MN|원소기호 MN - Manganese 함유량||
# |MO|원소기호 MO - Molybdenum 함유량||
# |NA|원소기호 NA - Sodium 함유량||
# |NI|원소기호 NI - Nickel 함유량||
# |P|원소기호 P - Phosphorus 함유량||
# |PB|원소기호 PB - Lead 함유량||
# |PQINDEX|Particle Quantifier Index||
# |S|원소기호 S - Sulphur 함유량||
# |SB|원소기호 SB - Antimony 함유량||
# |SI|원소기호 SI - Silicone 함유량||
# |SN|원소기호 SN - Tin 함유량||
# |SOOTPERCENTAGE|Soot 함유량(%)||
# |TI|원소기호 TI - Titanium 함유량||
# |U100|Particle Count (100μm 이상 크기 입자)||
# |U75|Particle Count (75μm 이상 크기 입자)||
# |U50|Particle Count (50μm 이상 크기 입자)||
# |U25|Particle Count (25μm 이상 크기 입자)||
# |U20|Particle Count (20μm 이상 크기 입자)||
# |U14|Particle Count (14μm 이상 크기 입자)||
# |U6|Particle Count (6μm 이상 크기 입자)||
# |U4|Particle Count (4μm 이상 크기 입자)||
# |V|원소기호 V - Vanadium 함유량||
# |V100|Viscosity @ 100 degrees||
# |V40|Viscosity @ 40 degrees||
# |ZN|원소기호 ZN - Zinc 함유량||
# |Y_LABEL|오일 정상 여부 (0 : 정상, 1 : 이상)||

# %%
# CD == 0
df.CD = df.CD.fillna(0)

# %%
sns.kdeplot(df.FH2O, shade=True)
# Out:
# /var/folders/3d/fksyvw8102q5p7zbsjrk_qs80000gn/T/ipykernel_33735/571166357.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df.FH2O, shade=True)
# <AxesSubplot: xlabel='FH2O', ylabel='Density'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14095 entries, 0 to 14094
# Data columns (total 54 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   14095 non-null  object
#  1   COMPONENT_ARBITRARY  14095 non-null  object
#  2   ANONYMOUS_1          14095 non-null  int64
#  3   YEAR                 14095 non-null  int64
#  4   SAMPLE_TRANSFER_DAY  14095 non-null  int64
#  5   ANONYMOUS_2          14095 non-null  int64
#  6   AG                   14095 non-null  int64
#  7   AL                   14095 non-null  int64
#  8   B                    14095 non-null  int64
#  9   BA                   14095 non-null  int64
#  10  BE                   14095 non-null  int64
#  11  CA                   14095 non-null  int64
#  12  CD                   14095 non-null  float64
#  13  CO                   14095 non-null  int64
#  14  CR                   14095 non-null  int64
# ...

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler


import os
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
import random

import warnings
warnings.filterwarnings(action='ignore') 

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('mps')

# %%
CFG = {
    'EPOCHS': 30,
    'LEARNING_RATE':1e-2,
    'BATCH_SIZE':256,
    'SEED':41
}

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(CFG['SEED'])

# %%
data_path = './data/'
train = pd.read_csv(f'{data_path}train.csv')
test = pd.read_csv(f'{data_path}test.csv')

# %%
categorical_features = ['COMPONENT_ARBITRARY', 'YEAR']
# Inference(실제 진단 환경)에 사용하는 컬럼
test_stage_features = ['COMPONENT_ARBITRARY', 'ANONYMOUS_1', 'YEAR' , 'ANONYMOUS_2', 'AG', 'CO', 'CR', 'CU', 'FE', 'H2O', 'MN', 'MO', 'NI', 'PQINDEX', 'TI', 'V', 'V40', 'ZN']

# %%
train.groupby(by = 'COMPONENT_ARBITRARY').mean()
# Out:
#                      ANONYMOUS_1         YEAR  SAMPLE_TRANSFER_DAY  \
# COMPONENT_ARBITRARY
# COMPONENT1           3046.162468  2013.729563             7.731620
# COMPONENT2           3023.936097  2013.718912             7.530225
# COMPONENT3           3227.621986  2013.494043             7.700426
# COMPONENT4           3261.377831  2014.443385             6.348033
#
#                      ANONYMOUS_2        AG         AL          B        BA  \
# COMPONENT_ARBITRARY
# COMPONENT1            392.906170  0.025193  10.285861  62.665553  0.643445
# COMPONENT2            383.064335  0.024180  18.402850  61.961572  0.780656
# COMPONENT3            381.766667  0.028227  12.999007  65.379858  0.703972
# COMPONENT4            421.458880  0.013111   5.767580  64.659118  0.585221
#
#                            BE           CA  ...        U25        U20  \
# COMPONENT_ARBITRARY                         ...
# COMPONENT1           0.012596  1397.478406  ...        NaN        NaN
# ...

# %%
test
# Out:
#              ID COMPONENT_ARBITRARY  ANONYMOUS_1  YEAR  ANONYMOUS_2  AG  CO  \
# 0     TEST_0000          COMPONENT1         2192  2016          200   0   0
# 1     TEST_0001          COMPONENT3         2794  2011          200   0   0
# 2     TEST_0002          COMPONENT2         1982  2010          200   0   0
# 3     TEST_0003          COMPONENT3         1404  2009          200   0   0
# 4     TEST_0004          COMPONENT2         8225  2013          200   0   0
# ...         ...                 ...          ...   ...          ...  ..  ..
# 6036  TEST_6036          COMPONENT3         1714  2014          200   0   0
# 6037  TEST_6037          COMPONENT3         4131  2016          200   0   0
# 6038  TEST_6038          COMPONENT3         4325  2014          200   0   0
# 6039  TEST_6039          COMPONENT2         1364  2013          200   0   0
# 6040  TEST_6040          COMPONENT1         2397  2016         1597   1   0
#
# ...
