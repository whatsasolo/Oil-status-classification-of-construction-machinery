# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = './data/'

df = pd.read_csv(f'{data_path}train.csv')
df_test = pd.read_csv(f'{data_path}test.csv')

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(16,5))

sns.heatmap(df.T.isna(), cmap='Blues')
ax.set_title('Missing Values', fontsize=16)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(5)
plt.show()
# Out:
# /var/folders/3d/fksyvw8102q5p7zbsjrk_qs80000gn/T/ipykernel_20482/1314153042.py:7: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(5)

# %%
df
# Out:
#           ID  COMPONENT_ARBITRARY  ANONYMOUS_1  YEAR  SAMPLE_TRANSFER_DAY  \
# 0          0                    3         1486  2011                    7
# 1          1                    2         1350  2021                   51
# 2          2                    2         2415  2015                    2
# 3          3                    3         7389  2010                    2
# 4          4                    3         3954  2015                    4
# ...      ...                  ...          ...   ...                  ...
# 14090  14090                    3         1616  2014                    8
# 14091  14091                    1         2784  2013                    2
# 14092  14092                    3         1788  2008                    9
# 14093  14093                    2         2498  2009                   19
# 14094  14094                    2         1902  2012                   15
#
#        ANONYMOUS_2  AG   AL    B  BA  ...     U25     U20      U14        U6  \
# ...

# %%
df[df.columns[df.isna().mean()>= 0.7]]
# Out:
#        FH2O  FNOX  FOPTIMETHGLY  FOXID  FSO4  FTBN  FUEL  SOOTPERCENTAGE  \
# 0       NaN   NaN           NaN    NaN   NaN   NaN   NaN             NaN
# 1       NaN   NaN           NaN    NaN   NaN   NaN   NaN             NaN
# 2       NaN   NaN           NaN    NaN   NaN   NaN   NaN             NaN
# 3       NaN   NaN           NaN    NaN   NaN   NaN   NaN             NaN
# 4       NaN   NaN           NaN    NaN   NaN   NaN   NaN             NaN
# ...     ...   ...           ...    ...   ...   ...   ...             ...
# 14090   NaN   NaN           NaN    NaN   NaN   NaN   NaN             NaN
# 14091  13.0   8.0           0.0   16.0  21.0   9.1   0.0             0.4
# 14092   NaN   NaN           NaN    NaN   NaN   NaN   NaN             NaN
# 14093   NaN   NaN           NaN    NaN   NaN   NaN   NaN             NaN
# 14094   NaN   NaN           NaN    NaN   NaN   NaN   NaN             NaN
#
#        U100  U75  U50     U25     U20      U14        U6        U4  V100
# ...

# %%
df[list(set(df.columns) - (set(df.columns) - set(df_test.columns)))].columns
# Out:
# Index(['CO', 'ID', 'COMPONENT_ARBITRARY', 'AG', 'H2O', 'TI', 'ANONYMOUS_1',
#        'CU', 'ZN', 'V40', 'ANONYMOUS_2', 'V', 'NI', 'YEAR', 'PQINDEX', 'MN',
#        'MO', 'CR', 'FE'],
#       dtype='object')

# %%
f, ax = plt.subplots(nrows=1, ncols=1, figsize=(16,5))

sns.heatmap(df[list(set(df.columns) - (set(df.columns) - set(df_test.columns)))].T.isna(), cmap='Blues')
ax.set_title('Missing Values', fontsize=16)

for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(12)
plt.show()
# Out:
# /var/folders/3d/fksyvw8102q5p7zbsjrk_qs80000gn/T/ipykernel_20482/68764265.py:7: MatplotlibDeprecationWarning: The label function was deprecated in Matplotlib 3.1 and will be removed in 3.8. Use Tick.label1 instead.
#   tick.label.set_fontsize(12)

# %%
df.Y_LABEL.mean()
# Out:
# 0.08534941468605889

# %%
# object -> int
df.COMPONENT_ARBITRARY = df.COMPONENT_ARBITRARY.apply(lambda x : int(x[-1]))
df.ID = df.ID.apply(lambda x : int(x[-5:]))

# %% [markdown]
# |Feature Name|Description|단위|처리 방법 및 비고|
# |------------|-----------|---:|-------------:|
# |COMPONENT_ARBITRARY|샘플 오일 관련 부품 (Component 4종, 비식별화)||결측치 없음|
# |ANONYMOUS_1|무명 Feautre 1. 수치형 데이터||결측치 없음|
# |YEAR|오일 샘플 및 진단 해 (Year)||결측치 없음|
# |SAMPLE_TRANSFER_DAY|오일 샘플링 후 진단 기관으로 이동한 기간 (Days)||결측치 없음|
# |ANONYMOUS_2|무명 Feautre 2. 수치형 데이터||결측치 없음|
# |AG|원소기호 AG - Silver 함유량|ppm|결측치 없음|
# |AL|원소기호 AL - Aluminium 함유량|ppm|결측치 없음|
# |B|원소기호 B - Boron 함유량|ppm|결측치 없음|
# |BA|원소기호 BA - Barium 함유량|ppm|결측치 없음|
# |BE|원소기호 BE - Beryllium 함유량|ppm|결측치 없음|
# |CA|원소기호 CA - Calcium 함유량|ppm|결측치 없음|
# |CD|~~원소기호 CD - Cadmium 함유량~~|ppm|결측치 ->0|
# |CO|원소기호 CO - Cobolt 함유량|ppm|결측치 없음|
# |CR|원소기호 CR - Chromium 함유량|ppm|결측치 없음|
# |CU|원소기호 CU - Copper 함유량|ppm|결측치 없음|
# |FH2O|Water 수치(By FT-IR)|단위 없음||
# |FNOX|NOx 수치(By FT-IR)|단위 없음||
# |FOPTIMETHGLY|비식별화|단위 없음||
# |FOXID|Oxidation 수치(By FT-IR)|단위 없음||
# |FSO4|SO4 수치(By FT-IR)|단위 없음||
# |FTBN|염기성 첨가제물질 수치(By FT-IR)|단위 없음||
# |FE|원소기호 FE - Iron 함유량|ppm||
# |FUEL|연료 함유량|%||
# |H2O|Water 함유량|ppm||
# |K|원소기호 K - Potassium 함유량|ppm||
# |LI|원소기호 LI - Lithium 함유량|ppm||
# |MG|원소기호 MG - Magnesium 함유량|ppm||
# |MN|원소기호 MN - Manganese 함유량|ppm||
# |MO|원소기호 MO - Molybdenum 함유량|ppm||
# |NA|원소기호 NA - Sodium 함유량|ppm||
# |NI|원소기호 NI - Nickel 함유량|ppm||
# |P|원소기호 P - Phosphorus 함유량|ppm||
# |PB|원소기호 PB - Lead 함유량|ppm||
# |PQINDEX|Particle Quantifier Index|단위 없음||
# |S|원소기호 S - Sulphur 함유량|ppm||
# |SB|원소기호 SB - Antimony 함유량|ppm||
# |SI|원소기호 SI - Silicone 함유량|ppm||
# |SN|원소기호 SN - Tin 함유량|ppm||
# |SOOTPERCENTAGE|Soot 함유량(%)|%||
# |TI|원소기호 TI - Titanium 함유량|ppm||
# |U100|Particle Count (100μm 이상 크기 입자)|particles/1mL||
# |U75|Particle Count (75μm 이상 크기 입자)|particles/1mL||
# |U50|Particle Count (50μm 이상 크기 입자)|particles/1mL||
# |U25|Particle Count (25μm 이상 크기 입자)|particles/1mL||
# |U20|Particle Count (20μm 이상 크기 입자)|particles/1mL||
# |U14|Particle Count (14μm 이상 크기 입자)|particles/1mL||
# |U6|Particle Count (6μm 이상 크기 입자)|particles/1mL||
# |U4|Particle Count (4μm 이상 크기 입자)|particles/1mL||
# |V|원소기호 V - Vanadium 함유량|ppm||
# |V100|Viscosity @ 100 degrees|cSt|centiStokes (1 cSt = 1mm^2/sec)|
# |V40|Viscosity @ 40 degrees|cSt|centiStokes (1 cSt = 1mm^2/sec)|
# |ZN|원소기호 ZN - Zinc 함유량|ppm||
# |Y_LABEL|오일 정상 여부 (0 : 정상, 1 : 이상)|||

# %% [markdown]
# ## 이상치 제거

# %%
plt.figure(figsize=(30,70))
plt.tight_layout()
plt.subplots_adjust(hspace=0.05, wspace = 0.5)
for index,col in enumerate(df.columns[1:-1]):
    plt.subplot(4,13,index+1)
    df.boxplot(column = col, grid=True, notch =True)
    # sns.boxplot(data = df[col])
    if len(col) > 10:
        plt.title(f'{col}',fontsize = 11)
    else:
        plt.title(f'{col}',fontsize = 16)
plt.show()

# %%
df[df.columns[1:-1]].hist(bins = 40, figsize=(20,30))
plt.show()

# %%
outlier_col = ['ANONYMOUS_1','SAMPLE_TRANSFER_DAY', 'ANONYMOUS_2', 'AG', 'AL', 'B', 'BA', 'BE', 'CA','CD', 
                'CO', 'CR', 'CU', 'FH2O', 'FNOX', 'FOPTIMETHGLY', 'FOXID', 'FSO4','FTBN', 'FE', 'FUEL', 'H2O', 
                'K', 'LI', 'MG', 'MN', 'MO', 'NA', 'NI','P', 'PB', 'PQINDEX', 'S', 'SB', 'SI', 'SN', 'SOOTPERCENTAGE', 
                'TI','U100', 'U75', 'U50', 'U25', 'U20', 'U14', 'U6', 'U4', 'V', 'V100','V40', 'ZN']
len(outlier_col)
# Out:
# 50

# %%
plt.figure(figsize=(30,70))
plt.tight_layout()
plt.subplots_adjust(hspace=0.05, wspace = 0.5)
for index,col in enumerate(outlier_col):
    plt.subplot(5,10,index+1)
    df.boxplot(column = col, grid=True, notch =True)
    # sns.boxplot(data = df[col])
    if len(col) > 10:
        plt.title(f'{col}',fontsize = 11)
    else:
        plt.title(f'{col}',fontsize = 16)
plt.show()

# %%
df[outlier_col].hist(bins = 40, figsize=(20,25))
plt.show()

# %%
Q1 = df[outlier_col].quantile(q=0.25)
Q3 = df[outlier_col].quantile(q=0.75)
IQR = Q3-Q1

# %%
df[(df["B"] <= Q3["B"]+1.5*IQR["B"]) & (df["B"] >= Q1["B"]-1.5*IQR["B"])]
# Out:
#           ID  COMPONENT_ARBITRARY  ANONYMOUS_1  YEAR  SAMPLE_TRANSFER_DAY  \
# 0          0                    3         1486  2011                    7
# 1          1                    2         1350  2021                   51
# 2          2                    2         2415  2015                    2
# 3          3                    3         7389  2010                    2
# 4          4                    3         3954  2015                    4
# ...      ...                  ...          ...   ...                  ...
# 14090  14090                    3         1616  2014                    8
# 14091  14091                    1         2784  2013                    2
# 14092  14092                    3         1788  2008                    9
# 14093  14093                    2         2498  2009                   19
# 14094  14094                    2         1902  2012                   15
#
#        ANONYMOUS_2  AG   AL    B  BA  ...     U25     U20      U14        U6  \
# ...

# %%
for i in IQR.keys()[1:]:
    print(i)
# Out:
# SAMPLE_TRANSFER_DAY
# ANONYMOUS_2
# AG
# AL
# B
# BA
# BE
# CA
# CD
# CO
# CR
# CU
# FH2O
# FNOX
# FOPTIMETHGLY
# FOXID
# FSO4
# FTBN
# FE
# FUEL
# H2O
# K
# LI
# MG
# MN
# MO
# NA
# NI
# P
# PB
# PQINDEX
# S
# SB
# SI
# SN
# SOOTPERCENTAGE
# TI
# U100
# U75
# U50
# U25
# U20
# U14
# U6
# U4
# V
# V100
# V40
# ZN

# %%
df
# Out:
#                 ID COMPONENT_ARBITRARY  ANONYMOUS_1  YEAR  \
# 0      TRAIN_00000          COMPONENT3         1486  2011
# 1      TRAIN_00001          COMPONENT2         1350  2021
# 2      TRAIN_00002          COMPONENT2         2415  2015
# 3      TRAIN_00003          COMPONENT3         7389  2010
# 4      TRAIN_00004          COMPONENT3         3954  2015
# ...            ...                 ...          ...   ...
# 14090  TRAIN_14090          COMPONENT3         1616  2014
# 14091  TRAIN_14091          COMPONENT1         2784  2013
# 14092  TRAIN_14092          COMPONENT3         1788  2008
# 14093  TRAIN_14093          COMPONENT2         2498  2009
# 14094  TRAIN_14094          COMPONENT2         1902  2012
#
#        SAMPLE_TRANSFER_DAY  ANONYMOUS_2  AG   AL    B  BA  ...     U25  \
# 0                        7          200   0    3   93   0  ...     NaN
# 1                       51          375   0    2   19   0  ...     2.0
# ...

# %%
original_df = df.copy()
IQR_df = df[(df['ANONYMOUS_1'] <= Q3['ANONYMOUS_1']+0.00001*IQR['ANONYMOUS_1']) & (df['ANONYMOUS_1'] >= Q1['ANONYMOUS_1']-0.00001*IQR['ANONYMOUS_1'])]
for i in IQR.keys()[1:]:
    IQR_df = IQR_df[(IQR_df[i] <= Q3[i]+0.00001*IQR[i]) & (IQR_df[i] >= Q1[i]-0.00001*IQR[i])]
# IQR_df = IQR_df[['AG','AL']]

print('original_df :', len(original_df))
print('IQR_df :', len(IQR_df))
# Out:
# original_df : 14095
# IQR_df : 0

# %%
IQR_df
# Out:
# Empty DataFrame
# Columns: [ID, COMPONENT_ARBITRARY, ANONYMOUS_1, YEAR, SAMPLE_TRANSFER_DAY, ANONYMOUS_2, AG, AL, B, BA, BE, CA, CD, CO, CR, CU, FH2O, FNOX, FOPTIMETHGLY, FOXID, FSO4, FTBN, FE, FUEL, H2O, K, LI, MG, MN, MO, NA, NI, P, PB, PQINDEX, S, SB, SI, SN, SOOTPERCENTAGE, TI, U100, U75, U50, U25, U20, U14, U6, U4, V, V100, V40, ZN, Y_LABEL]
# Index: []
#
# [0 rows x 54 columns]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler


import os
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
import random

import warnings
warnings.filterwarnings(action='ignore') 

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('mps')

# %%
CFG = {
    'EPOCHS': 30,
    'LEARNING_RATE':1e-2,
    'BATCH_SIZE':256,
    'SEED':41
}

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(CFG['SEED'])

# %%
data_path = './data/'
train = pd.read_csv(f'{data_path}train.csv')
test = pd.read_csv(f'{data_path}test.csv')

# %%
categorical_features = ['COMPONENT_ARBITRARY', 'YEAR']
# Inference(실제 진단 환경)에 사용하는 컬럼
test_stage_features = ['COMPONENT_ARBITRARY', 'ANONYMOUS_1', 'YEAR' , 'ANONYMOUS_2', 'AG', 'CO', 'CR', 'CU', 'FE', 'H2O', 'MN', 'MO', 'NI', 'PQINDEX', 'TI', 'V', 'V40', 'ZN']

# %%
train.groupby(by = 'COMPONENT_ARBITRARY').mean()
# Out:
#                      ANONYMOUS_1         YEAR  SAMPLE_TRANSFER_DAY  \
# COMPONENT_ARBITRARY
# COMPONENT1           3046.162468  2013.729563             7.731620
# COMPONENT2           3023.936097  2013.718912             7.530225
# COMPONENT3           3227.621986  2013.494043             7.700426
# COMPONENT4           3261.377831  2014.443385             6.348033
#
#                      ANONYMOUS_2        AG         AL          B        BA  \
# COMPONENT_ARBITRARY
# COMPONENT1            392.906170  0.025193  10.285861  62.665553  0.643445
# COMPONENT2            383.064335  0.024180  18.402850  61.961572  0.780656
# COMPONENT3            381.766667  0.028227  12.999007  65.379858  0.703972
# COMPONENT4            421.458880  0.013111   5.767580  64.659118  0.585221
#
#                            BE           CA  ...        U25        U20  \
# COMPONENT_ARBITRARY                         ...
# COMPONENT1           0.012596  1397.478406  ...        NaN        NaN
# ...

# %%
test
# Out:
#              ID COMPONENT_ARBITRARY  ANONYMOUS_1  YEAR  ANONYMOUS_2  AG  CO  \
# 0     TEST_0000          COMPONENT1         2192  2016          200   0   0
# 1     TEST_0001          COMPONENT3         2794  2011          200   0   0
# 2     TEST_0002          COMPONENT2         1982  2010          200   0   0
# 3     TEST_0003          COMPONENT3         1404  2009          200   0   0
# 4     TEST_0004          COMPONENT2         8225  2013          200   0   0
# ...         ...                 ...          ...   ...          ...  ..  ..
# 6036  TEST_6036          COMPONENT3         1714  2014          200   0   0
# 6037  TEST_6037          COMPONENT3         4131  2016          200   0   0
# 6038  TEST_6038          COMPONENT3         4325  2014          200   0   0
# 6039  TEST_6039          COMPONENT2         1364  2013          200   0   0
# 6040  TEST_6040          COMPONENT1         2397  2016         1597   1   0
#
# ...

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6041 entries, 0 to 6040
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   6041 non-null   object
#  1   COMPONENT_ARBITRARY  6041 non-null   object
#  2   ANONYMOUS_1          6041 non-null   int64
#  3   YEAR                 6041 non-null   int64
#  4   ANONYMOUS_2          6041 non-null   int64
#  5   AG                   6041 non-null   int64
#  6   CO                   6041 non-null   int64
#  7   CR                   6041 non-null   int64
#  8   CU                   6041 non-null   int64
#  9   FE                   6041 non-null   int64
#  10  H2O                  6041 non-null   float64
#  11  MN                   6041 non-null   int64
#  12  MO                   6041 non-null   int64
#  13  NI                   6041 non-null   int64
#  14  PQINDEX              6041 non-null   int64
# ...
